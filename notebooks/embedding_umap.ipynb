# %%
import numpy as np
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
sns.set(style='white', context='notebook', rc={'figure.figsize':(14,10)})

# %%
kgcovid = pd.read_csv("./embedded_graph.embedded",index_col=0, sep=" ")
#kgcovid = pd.io.parsers.read_csv("embedded_graph.embedded",sep="\t",index_col=0)
kgcovid.head()
# Out:
#                          0.8357057  -2.5257075  1.2508836  -0.93386036  \
# ENSEMBL:ENSG00000004059
# ENSEMBL:ENSG00000104915  -0.354009    0.171892  -0.839815     0.900131
# ENSEMBL:ENSG00000131089   0.684730   -0.904100  -0.615515     0.035993
# ENSEMBL:ENSG00000143933  -0.535080    0.806421   1.058282    -1.891660
# ENSEMBL:ENSG00000147889  -1.977005   -0.691585   0.375624    -0.617985
# ENSEMBL:ENSG00000178607  -1.343207   -0.199554  -0.337470     1.582666
#
#                          -0.42099625  -1.7337036  -0.19745654  0.3848471  \
# ENSEMBL:ENSG00000004059
# ENSEMBL:ENSG00000104915    -0.287063    0.834030     0.546791  -1.116834
# ENSEMBL:ENSG00000131089    -0.428221    0.250868    -0.475172  -1.414714
# ENSEMBL:ENSG00000143933    -1.576680    0.264754    -0.093651   0.427031
# ENSEMBL:ENSG00000147889    -0.278732    0.581232     1.614157  -0.339553
# ENSEMBL:ENSG00000178607    -1.186207   -0.088155     1.187215  -0.522183
#
# ...

# %%
import umap
import umap.plot

# %%
reducer = umap.UMAP()

# %%
embedding = reducer.fit_transform(kgcovid)
embedding.shape
# Out:
# (6484, 2)

# %%
plt.scatter(
    embedding[:, 0],
    embedding[:, 1])
    #c=[sns.color_palette()[x] for x in penguins.species_short.map({"Adelie":0, "Chinstrap":1, "Gentoo":2})])
    
plt.gca().set_aspect('equal', 'datalim')
plt.title('UMAP projection of first KG-COVID embeddings', fontsize=24)
# Out:
# Text(0.5, 1.0, 'UMAP projection of first KG-COVID embeddings')

# %%
umap.plot.points(embedding, labels=kgcovid.target)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-03797ebd6878> in <module>
# ----> 1 umap.plot.points(embedding, labels=kgcovid.target)
#
# ~/Library/Python/3.7/lib/python/site-packages/pandas-1.0.1-py3.7-macosx-10.9-x86_64.egg/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'target'
